# %% [markdown]
# # Model Training Example
#
# This notebook demonstrates training a predictive model for inverter failure prediction.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from src.config.settings import DEFAULT_CONFIG
from src.features.feature_engineering import engineer_features
from src.models.training import train_inverter_failure_model, save_model
from src.models.evaluation import generate_evaluation_report

plt.rcParams["figure.figsize"] = (10, 6)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       2 from pathlib import Path
#       4 sys.path.insert(0, str(Path.cwd().parent / "src"))
# ----> 6 import pandas as pd
#       7 import numpy as np
#       8 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
